# %% [markdown]
# <p style="font-family: Lorem ipsum; font-size: 16px; color: black;">
# <strong>F78DS Data Science Life Cycle</strong><br>
# <strong>Coursework 1</strong><br>
# <strong>Basil Rehan Siddiqui</strong><br>
# <strong>H00435838</strong>
# </p>

# %%
# Import pandas library for data manipulation and analysis
import pandas as pd
# Import matplotlib.pyplot for creating visualizations
import matplotlib.pyplot as plt

# %% [markdown]
# **I will first find insights on each dataset individually, and then towards the end I will try to get more information by joining the datasets**

# %% [markdown]
# **DATASET 1 : GDP**

# %%
GDP = pd.read_excel("GDP.xls", engine="xlrd") #pip install xlrd 
# Had to install xlrd to read .xls (older Excel) files in pandas
GDP.head()
# Out:
#                    Data Source World Development Indicators  \
# 0            Last Updated Date          2025-01-28 00:00:00
# 1                          NaN                          NaN
# 2                 Country Name                 Country Code
# 3                        Aruba                          ABW
# 4  Africa Eastern and Southern                          AFE
#
#           Unnamed: 2      Unnamed: 3     Unnamed: 4     Unnamed: 5  \
# 0                NaN             NaN            NaN            NaN
# 1                NaN             NaN            NaN            NaN
# 2     Indicator Name  Indicator Code        1960.00        1961.00
# 3  GDP (current US$)  NY.GDP.MKTP.CD            NaN            NaN
# 4  GDP (current US$)  NY.GDP.MKTP.CD 24210632546.41 24963977550.73
#
#       Unnamed: 6     Unnamed: 7     Unnamed: 8     Unnamed: 9  ...  \
# 0            NaN            NaN            NaN            NaN  ...
# ...

# %%
GDP = pd.read_excel("GDP.xls", header = 3) # Removing the top 3 rows and adjusting to new header
GDP.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code           1960           1961           1962           1963  \
# 0  NY.GDP.MKTP.CD            NaN            NaN            NaN            NaN
# 1  NY.GDP.MKTP.CD 24210632546.41 24963977550.73 27078797298.77 31775749181.24
# 2  NY.GDP.MKTP.CD            NaN            NaN            NaN            NaN
# 3  NY.GDP.MKTP.CD 11904954209.79 12707877772.09 13630758805.13 14469094143.85
# 4  NY.GDP.MKTP.CD            NaN            NaN            NaN            NaN
#
#             1964           1965  ...            2014            2015  \
# ...

# %%
GDP.shape # We can see that there are 266 countries and 68 columns
# Out:
# (266, 68)

# %%
GDP.head()
# Out:
#                   Country Name Country Code     Indicator Name  \
# 0                        Aruba          ABW  GDP (current US$)
# 1  Africa Eastern and Southern          AFE  GDP (current US$)
# 2                  Afghanistan          AFG  GDP (current US$)
# 3   Africa Western and Central          AFW  GDP (current US$)
# 4                       Angola          AGO  GDP (current US$)
#
#    Indicator Code           1960           1961           1962           1963  \
# 0  NY.GDP.MKTP.CD            NaN            NaN            NaN            NaN
# 1  NY.GDP.MKTP.CD 24210632546.41 24963977550.73 27078797298.77 31775749181.24
# 2  NY.GDP.MKTP.CD            NaN            NaN            NaN            NaN
# 3  NY.GDP.MKTP.CD 11904954209.79 12707877772.09 13630758805.13 14469094143.85
# 4  NY.GDP.MKTP.CD            NaN            NaN            NaN            NaN
#
#             1964           1965  ...            2014            2015  \
# ...

# %%
GDP.columns # Checking columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022',
#        '2023'],
#       dtype='object')

# %%
unique_country_names = GDP['Country Name'].unique() #M ake sure no countries are repeating
len(unique_country_names) # Should be 266
# Out:
# 266

# %%
unique_country_codes = GDP['Country Code'].unique() # Make sure no countries are repeating
len(unique_country_codes) # Should be 266
# Out:
# 266

# %%
unique_indicator_names = GDP['Indicator Name'].unique() # Make sure no indicators are repeating
len(unique_indicator_names) # Should be 266
# Out:
# 1

# %%
GDP = GDP.drop('Indicator Name', axis=1) # Since all the rows are same in this column, its best if we just delete it

# %%
unique_indicator_codes = GDP['Indicator Code'].unique() # Make sure no indicator codes are repeating
len(unique_indicator_codes) # Should be 266
# Out:
# 1

# %%
GDP = GDP.drop('Indicator Code', axis=1) # Since all the rows are same in this column, its best if we just delete it

# %%
GDP.shape # Making sure the 2 columns are deleted
# Out:
# (266, 66)

# %%
GDP.columns # Checking which years are mentioned, its from 1960 to 2023
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018',
#        '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')

# %%
GDP_filtered = GDP[GDP['Country Name'].isin(['United Kingdom', 'United Arab Emirates', 'Malaysia'])] # Filter rows where 'Country Name' is UK, UAE, or Malaysia

# %%
GDP_filtered = GDP_filtered.fillna(0) # Replace NaN with 0 in the entire DataFrame, may help with analysis later on

# %%
GDP_filtered
# Out:
#              Country Name Country Code           1960           1961  \
# 8    United Arab Emirates          ARE           0.00           0.00
# 81         United Kingdom          GBR 73233967692.10 77741965703.35
# 169              Malaysia          MYS  1916229477.14  1901856122.72
#
#               1962           1963           1964            1965  \
# 8             0.00           0.00           0.00            0.00
# 81  81247564156.82 86561961812.32 94407558351.16 101824755078.99
# 169  2001489602.18  2510110348.16  2674423922.49   2956337669.30
#
#                1966            1967  ...             2014             2015  \
# 8              0.00            0.00  ...  414105366758.91  370275469560.17
# 81  108572752102.04 113116888210.79  ... 3064708247921.43 2927911140916.73
# 169   3143517943.83   3188924677.09  ...  338066095097.25  301355266964.95
#
#                 2016             2017             2018             2019  \
# ...

# %%
pd.set_option('display.float_format', '{:.2f}'.format)  # Converting the numbers into 'float' and rounding all numeric columns to 2 decimal places

# %%
GDP_filtered
# Out:
#              Country Name Country Code           1960           1961  \
# 8    United Arab Emirates          ARE           0.00           0.00
# 81         United Kingdom          GBR 73233967692.10 77741965703.35
# 169              Malaysia          MYS  1916229477.14  1901856122.72
#
#               1962           1963           1964            1965  \
# 8             0.00           0.00           0.00            0.00
# 81  81247564156.82 86561961812.32 94407558351.16 101824755078.99
# 169  2001489602.18  2510110348.16  2674423922.49   2956337669.30
#
#                1966            1967  ...             2014             2015  \
# 8              0.00            0.00  ...  414105366758.91  370275469560.17
# 81  108572752102.04 113116888210.79  ... 3064708247921.43 2927911140916.73
# 169   3143517943.83   3188924677.09  ...  338066095097.25  301355266964.95
#
#                 2016             2017             2018             2019  \
# ...

# %%
GDP2023 = GDP_filtered[['Country Name','2023']] # Filtering most recent GDP for latest proportions

# %%
GDP2023.set_index('Country Name', inplace=True) # Set 'Country Name' as the index

GDP2023['2023'].plot.bar(
    color=["red", "green", "blue"],  # Apply the basic RGB
    figsize=(6, 6),
    edgecolor='black',  # Add black border to the bars 
)

# Adding labels and title for clarity
plt.xlabel('Country', fontsize=12)
plt.ylabel('GDP (trillion USD)', fontsize=12)
plt.title('GDP of Countries in 2023', fontsize=16, loc='center')
# Out:
# Text(0.5, 1.0, 'GDP of Countries in 2023')

# %% [markdown]
# *We can see that the UK is way ahead in terms of GDP compared to the UAE and Malaysia*

# %%
GDP2023 = GDP_filtered[['Country Name','2023']] # Filtering most recent GDP for latest proportions

# %%
GDP2023.set_index('Country Name', inplace=True)

GDP2023['2023'].plot.pie(
    autopct='%1.1f%%', 
    colors=["red","green","blue"], 
    figsize=(6, 6), 
    legend=False, # No legend as labels are already there
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},  # Add black edge to the slices (makes it look cleaner)
)

# Title and layout adjustments
plt.title('GDP Distribution in 2023 between UAE, UK and Malaysia', fontsize=16, loc='center')
plt.ylabel('')  # Remove the y-label for aesthetics
plt.show()

# %% [markdown]
# *The UK's GDP is more than 3.5x times larger than Malaysia and the UAE combined.*

# %%
GDP_numeric = GDP_filtered.drop('Country Code', axis=1) # Exclude Country Code and for only numeric columns
GDP_numeric.set_index('Country Name', inplace=True)

# Plotting the data for all countries
GDP_numeric.T.plot(kind='line', figsize=(10, 6)) # Each row in the transposed DataFrame represents a year

# Adding labels and title for clarity
plt.xlabel('Year', fontsize=12)
plt.ylabel('GDP (trillion USD)', fontsize=12)
plt.title('GDP of Countries from 1960 to 2023', fontsize=16)

# Show the legend
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# *From the beginning (1960), Malaysia and UAE didn't exist so it is a straight line until the countries were formed, the 2 countries generally grew overtime but very little compared to the rate of the UK which grew rapidly. The UK had a few major drops between 2005 and 2015.*

# %% [markdown]
# **DATESET 2 : WPP**

# %%
WPP = pd.read_csv("WPP2024_ByAge.csv", low_memory=False) # To avoid data type mismatches in large datasets.

# %%
WPP.columns
# Out:
# Index(['SortOrder', 'LocID', 'Notes', 'ISO3_code', 'ISO2_code', 'SDMX_code',
#        'LocTypeID', 'LocTypeName', 'ParentID', 'Location', 'VarID', 'Variant',
#        'Time', 'MidPeriod', 'AgeGrp', 'AgeGrpStart', 'AgeGrpSpan', 'PopMale',
#        'PopFemale', 'PopTotal'],
#       dtype='object')

# %%
WPP['LocTypeID'].unique() # Checking in which column are the countries
# Out:
# array([nan,  1., 12.,  5., 13., 14.,  2.,  3.,  4.])

# %%
WPP_filtered = WPP[WPP['Location'].isin(['United Kingdom', 'United Arab Emirates', 'Malaysia'])] # Filter rows where 'Location' is UK, UAE, or Malaysia
# I am ignoring the 'United Kingdom (and dependencies)' and only considering 'United Kingdom' for clarity

# %%
WPP_filtered
# Out:
#          SortOrder  LocID Notes ISO3_code ISO2_code  SDMX_code  LocTypeID  \
# 2877490     157.00    458     9       MYS        MY     458.00       4.00
# 2877491     157.00    458     9       MYS        MY     458.00       4.00
# 2877492     157.00    458     9       MYS        MY     458.00       4.00
# 2877493     157.00    458     9       MYS        MY     458.00       4.00
# 2877494     157.00    458     9       MYS        MY     458.00       4.00
# ...            ...    ...   ...       ...       ...        ...        ...
# 3273607     209.00    826    21       GBR        GB     826.00       4.00
# 3273608     209.00    826    21       GBR        GB     826.00       4.00
# 3273609     209.00    826    21       GBR        GB     826.00       4.00
# 3273610     209.00    826    21       GBR        GB     826.00       4.00
# 3273611     209.00    826    21       GBR        GB     826.00       4.00
#
#           LocTypeName  ParentID        Location  VarID Variant  Time  \
# ...

# %%
for col in WPP_filtered.columns: # Making sure if each column is relevant or not
    print(f"Unique values in '{col}':")
    print(WPP_filtered[col].unique(), "\n")
# Out:
# Unique values in 'SortOrder':
# [157. 181. 209.]
#
# Unique values in 'LocID':
# [458 784 826]
#
# Unique values in 'Notes':
# ['9' nan '21']
#
# Unique values in 'ISO3_code':
# ['MYS' 'ARE' 'GBR']
#
# Unique values in 'ISO2_code':
# ['MY' 'AE' 'GB']
#
# Unique values in 'SDMX_code':
# [458. 784. 826.]
#
# Unique values in 'LocTypeID':
# [4.]
#
# Unique values in 'LocTypeName':
# ['Country/Area']
#
# Unique values in 'ParentID':
# [920. 922. 924.]
#
# Unique values in 'Location':
# ['Malaysia' 'United Arab Emirates' 'United Kingdom']
#
# Unique values in 'VarID':
# [2]
#
# Unique values in 'Variant':
# ['Medium']
#
# Unique values in 'Time':
# [1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962 1963
#  1964 1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977
#  1978 1979 1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991
#  1992 1993 1994 1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005
# ...

# %%
columns_to_keep = ['Location', 'Time', 'MidPeriod', 'AgeGrpStart', 'PopMale', 'PopFemale', 'PopTotal']  # Keeping these columns and removing the irrelevant ones
WPP_filtered = WPP_filtered[columns_to_keep]
WPP_filtered # Population is in thousands according to the source of data
# Out:
#                Location  Time  MidPeriod  AgeGrpStart  PopMale  PopFemale  \
# 2877490        Malaysia  1950       1950            0   113.41     110.86
# 2877491        Malaysia  1950       1950            1   103.20     101.31
# 2877492        Malaysia  1950       1950            2    95.49      95.39
# 2877493        Malaysia  1950       1950            3    87.84      87.49
# 2877494        Malaysia  1950       1950            4    82.39      81.77
# ...                 ...   ...        ...          ...      ...        ...
# 3273607  United Kingdom  2023       2023           96     9.46      23.77
# 3273608  United Kingdom  2023       2023           97     6.42      17.46
# 3273609  United Kingdom  2023       2023           98     4.10      12.28
# 3273610  United Kingdom  2023       2023           99     2.55       8.48
# 3273611  United Kingdom  2023       2023          100     3.35      14.09
#
#          PopTotal
# 2877490    224.27
# 2877491    204.51
# 2877492    190.88
# ...

# %%
WPP_filtered2 = WPP_filtered #Duplicating the dataframe so we dont mix them later on
WPP_filtered2 = WPP_filtered2.groupby(['Location','Time','AgeGrpStart']).sum()
WPP_filtered2 = WPP_filtered2[['PopTotal']]
WPP_filtered2 = WPP_filtered2.reset_index()

# %% [markdown]
# *I will seperate each country and apply their own age restrictions and join the data back for the working population
#
#   **Malaysia Working Age Population:**
# - Definition: 15-64 years
# - Source: Department of Statistics Malaysia (DOSM), World Bank, ILO
#
#   **United Kingdom (UK) Working Age Population:**
# - Definition: 16-64 years (UK uses 16 instead of 15)
# - Source: Office for National Statistics (ONS), UK Government, World Bank
#
#   **United Arab Emirates (UAE) Working Age Population:**
# - Definition: 15-64 years
# - Source: Federal Competitiveness and Statistics Centre (FCSC), UAE Ministry of Human Resources and Emiratisation (MOHRE), World Bank*

# %%
malaysia_data = WPP_filtered2[WPP_filtered2["Location"] == "Malaysia"]
malaysia_data
# Out:
#       Location  Time  AgeGrpStart  PopTotal
# 0     Malaysia  1950            0    224.27
# 1     Malaysia  1950            1    204.51
# 2     Malaysia  1950            2    190.88
# 3     Malaysia  1950            3    175.33
# 4     Malaysia  1950            4    164.16
# ...        ...   ...          ...       ...
# 7469  Malaysia  2023           96      2.57
# 7470  Malaysia  2023           97      1.77
# 7471  Malaysia  2023           98      1.26
# 7472  Malaysia  2023           99      0.94
# 7473  Malaysia  2023          100      1.93
#
# [7474 rows x 4 columns]

# %%
malaysia_data = malaysia_data[(malaysia_data['AgeGrpStart'] >= 15) & (malaysia_data['AgeGrpStart'] <= 64)]
malaysia_data
# Out:
#       Location  Time  AgeGrpStart  PopTotal
# 15    Malaysia  1950           15    124.40
# 16    Malaysia  1950           16    115.94
# 17    Malaysia  1950           17    111.42
# 18    Malaysia  1950           18    110.29
# 19    Malaysia  1950           19    109.94
# ...        ...   ...          ...       ...
# 7433  Malaysia  2023           60    286.79
# 7434  Malaysia  2023           61    275.17
# 7435  Malaysia  2023           62    262.99
# 7436  Malaysia  2023           63    250.78
# 7437  Malaysia  2023           64    237.96
#
# [3700 rows x 4 columns]

# %%
print(WPP_filtered2.head())
# Out:
#    Location  Time  AgeGrpStart  PopTotal
# 0  Malaysia  1950            0    224.27
# 1  Malaysia  1950            1    204.51
# 2  Malaysia  1950            2    190.88
# 3  Malaysia  1950            3    175.33
# 4  Malaysia  1950            4    164.16

# %%
UAE_data = WPP_filtered2[WPP_filtered2["Location"] == "United Arab Emirates"]
UAE_data = UAE_data[(UAE_data['AgeGrpStart'] >= 15) & (UAE_data['AgeGrpStart'] <= 64)]
UAE_data
# Out:
#                    Location  Time  AgeGrpStart  PopTotal
# 7489   United Arab Emirates  1950           15      1.52
# 7490   United Arab Emirates  1950           16      1.48
# 7491   United Arab Emirates  1950           17      1.44
# 7492   United Arab Emirates  1950           18      1.40
# 7493   United Arab Emirates  1950           19      1.35
# ...                     ...   ...          ...       ...
# 14907  United Arab Emirates  2023           60     48.14
# 14908  United Arab Emirates  2023           61     39.06
# 14909  United Arab Emirates  2023           62     33.80
# 14910  United Arab Emirates  2023           63     29.41
# 14911  United Arab Emirates  2023           64     24.51
#
# [3700 rows x 4 columns]

# %%
UK_data = WPP_filtered2[WPP_filtered2["Location"] == "United Kingdom"]
UK_data = UK_data[(UK_data['AgeGrpStart'] >= 16) & (UK_data['AgeGrpStart'] <= 64)]
UK_data
# Out:
#              Location  Time  AgeGrpStart  PopTotal
# 14964  United Kingdom  1950           16    614.83
# 14965  United Kingdom  1950           17    622.64
# 14966  United Kingdom  1950           18    630.92
# 14967  United Kingdom  1950           19    633.76
# 14968  United Kingdom  1950           20    642.65
# ...               ...   ...          ...       ...
# 22381  United Kingdom  2023           60    848.62
# 22382  United Kingdom  2023           61    839.51
# 22383  United Kingdom  2023           62    800.83
# 22384  United Kingdom  2023           63    782.97
# 22385  United Kingdom  2023           64    788.86
#
# [3626 rows x 4 columns]

# %%
WPP_filtered2 = pd.concat([malaysia_data, UK_data, UAE_data], ignore_index=True)

# %%
WPP_filtered2
# Out:
#                    Location  Time  AgeGrpStart  PopTotal
# 0                  Malaysia  1950           15    124.40
# 1                  Malaysia  1950           16    115.94
# 2                  Malaysia  1950           17    111.42
# 3                  Malaysia  1950           18    110.29
# 4                  Malaysia  1950           19    109.94
# ...                     ...   ...          ...       ...
# 11021  United Arab Emirates  2023           60     48.14
# 11022  United Arab Emirates  2023           61     39.06
# 11023  United Arab Emirates  2023           62     33.80
# 11024  United Arab Emirates  2023           63     29.41
# 11025  United Arab Emirates  2023           64     24.51
#
# [11026 rows x 4 columns]

# %% [markdown]
# **"**************************************************************"**

# %%
WPP_filtered2 = WPP_filtered2.reset_index()

WPP_filtered2 = WPP_filtered2[(WPP_filtered2['AgeGrpStart'] >= 15) & (WPP_filtered2['AgeGrpStart'] <= 60)]

WPP_filtered2
# Out:
#        index              Location  Time  AgeGrpStart  PopTotal
# 0          0              Malaysia  1950           15    124.40
# 1          1              Malaysia  1950           16    115.94
# 2          2              Malaysia  1950           17    111.42
# 3          3              Malaysia  1950           18    110.29
# 4          4              Malaysia  1950           19    109.94
# ...      ...                   ...   ...          ...       ...
# 11017  11017  United Arab Emirates  2023           56     78.66
# 11018  11018  United Arab Emirates  2023           57     70.50
# 11019  11019  United Arab Emirates  2023           58     65.07
# 11020  11020  United Arab Emirates  2023           59     58.34
# 11021  11021  United Arab Emirates  2023           60     48.14
#
# [10138 rows x 5 columns]

# %%
WPP_grouped = WPP_filtered2.groupby(["Location", "Time"]).sum("PopTotal").reset_index()
WPP_grouped
# Out:
#            Location  Time   index  AgeGrpStart  PopTotal
# 0          Malaysia  1950    1035         1725   3161.55
# 1          Malaysia  1951    3335         1725   3238.92
# 2          Malaysia  1952    5635         1725   3325.68
# 3          Malaysia  1953    7935         1725   3420.23
# 4          Malaysia  1954   10235         1725   3515.33
# ..              ...   ...     ...          ...       ...
# 217  United Kingdom  2019  319635         1710  38855.20
# 218  United Kingdom  2020  321840         1710  38875.35
# 219  United Kingdom  2021  324045         1710  38909.14
# 220  United Kingdom  2022  326250         1710  39187.57
# 221  United Kingdom  2023  328455         1710  39358.66
#
# [222 rows x 5 columns]

# %%
plt.figure(figsize=(12, 6)) # Set figure size

countries = WPP_grouped["Location"].unique() # Get unique countries

for country in countries: # Plot each country's data
    data = WPP_grouped[WPP_grouped["Location"] == country]
    plt.plot(data["Time"], data["PopTotal"], marker="o", linestyle="-", label=country)

# Labels and title
plt.xlabel("Year")
plt.ylabel("Working Age Population (15-60)")
plt.title("Working Age Population Trend (1950-2023)")
plt.legend(title="Country")
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# *We assumed that working population is 15-64 for the UAE and Malaysia, 16-64 for the UK, we can see that the UK is tremendously ahead compared to the UAE and Malaysia.*

# %%
WPP_filtered_2023 = WPP_filtered[WPP_filtered['Time']==2023]

# %%
WPP_filtered_2023.shape #Now its only for data from 2023
# Out:
# (303, 7)

# %%
WPP_filtered_2023
# Out:
#                Location  Time  MidPeriod  AgeGrpStart  PopMale  PopFemale  \
# 2884863        Malaysia  2023       2023            0   221.99     208.67
# 2884864        Malaysia  2023       2023            1   220.25     207.08
# 2884865        Malaysia  2023       2023            2   235.62     221.43
# 2884866        Malaysia  2023       2023            3   243.77     231.89
# 2884867        Malaysia  2023       2023            4   263.20     254.24
# ...                 ...   ...        ...          ...      ...        ...
# 3273607  United Kingdom  2023       2023           96     9.46      23.77
# 3273608  United Kingdom  2023       2023           97     6.42      17.46
# 3273609  United Kingdom  2023       2023           98     4.10      12.28
# 3273610  United Kingdom  2023       2023           99     2.55       8.48
# 3273611  United Kingdom  2023       2023          100     3.35      14.09
#
#          PopTotal
# 2884863    430.66
# 2884864    427.33
# 2884865    457.05
# ...

# %%
WPP_filtered_gender_ratio = WPP_filtered_2023.groupby(['Location']).sum(['PopMale','PopFemale'])
WPP_filtered_gender_ratio
# Out:
#                         Time  MidPeriod  AgeGrpStart  PopMale  PopFemale  \
# Location
# Malaysia              204323     204323         5050 18305.78   16602.58
# United Arab Emirates  204323     204323         5050  6691.07    3753.96
# United Kingdom        204323     204323         5050 33691.21   34751.67
#
#                       PopTotal
# Location
# Malaysia              34908.35
# United Arab Emirates  10445.03
# United Kingdom        68442.88

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 5)) # Set up the figure and axes for 3 pie charts

# Iterate over each location and plot a pie chart
for i, (location, row) in enumerate(WPP_filtered_gender_ratio.iterrows()):
    data = [row["PopMale"], row["PopFemale"]]
    labels = ["Male", "Female"]
    
    # Plot the pie chart in the corresponding subplot
    axes[i].pie(data, labels=labels, autopct="%1.1f%%", startangle=90, colors=["blue", "pink"])
    axes[i].set_title(location)

# Adjust layout for better spacing
plt.tight_layout()
plt.show()

# %% [markdown]
# *It seems that the UK and Malaysia have pretty balanced ratios in terms of genders, the UAE is quite male dominant with 64.1% male, probably because of the labours coming in to the UAE.*

# %%
def plot_population_by_age(country_name, data): #Making a function so I dont have to type the same code for each of the 3 countries
    """
    Plots a bar graph of population by age group for a specific country.

    Parameters:
        country_name (str): Name of the country to filter data for.
        data (pd.DataFrame): DataFrame containing the population data.
    """
    # Filter data for the specified country
    country_data = data[data['Location'] == country_name]

    # Create the bar graph
    plt.figure(figsize=(12, 6)) # I usually go for (6,6) but it makes it easier to interpret with a longer x axis
    plt.bar(country_data['AgeGrp'], country_data['PopTotal'], color='skyblue')

    # Add labels and title
    plt.xlabel('Age Group', fontsize=12)
    plt.ylabel('Total Population (thousands)', fontsize=12)
    plt.title(f'Population of {country_name} by Age Group (2023)', fontsize=16)
    
    plt.show() # Display the plot

# %%
plot_population_by_age('United Arab Emirates', WPP)

# %% [markdown]
# *We can see that there are 2 peaks for the UAE, one of the peak is around the age of 8 and the other is at 32. There's a little peak from 0-12, because of the immigrants moving in and having children in the UAE, we can see a downfall at around 17 due to students going abroad for higher studies. A peak at 32 because thats when most people come to work in the UAE for financial stability.*

# %%
plot_population_by_age('United Kingdom', WPP)

# %% [markdown]
# *It seems that there aren't any visibile peaks for the UK, we can notice that after ages of 55 to 58, the population starts to decline. Its constant.*

# %%
plot_population_by_age('Malaysia', WPP)

# %% [markdown]
# *We can see that there is a peak for Malaysia, the peak being around the age of 30 - 31, after which it declines.*

# %%
WPP_population_by_country = WPP_filtered.groupby('Location')['PopTotal'].sum().reset_index() # Grouping the dataset by 'Location' (Country) and summing the 'PopTotal' column
WPP_population_by_country = WPP_population_by_country.sort_values(by='PopTotal', ascending=False) # Sorting countries with highest first
WPP_population_by_country # Grouping the total populations with the 3 countries
# Out:
#                Location   PopTotal
# 2        United Kingdom 4279340.23
# 0              Malaysia 1312630.44
# 1  United Arab Emirates  212847.99

# %%
WPP_population_by_country.plot.barh(x='Location', y='PopTotal', figsize=(6, 6), legend=True, color='orange',edgecolor='black') # Colors are alwyas nice
plt.xlabel("Total Population (millions)")
plt.ylabel("Country")
plt.title("Total Population by Country") # Had to specify the parameter to make sure people understand it better
# Out:
# Text(0.5, 1.0, 'Total Population by Country')

# %% [markdown]
# *After visualising we realise how big of a difference the population is of the UK compared to the UAE and Malaysia*

# %% [markdown]
# **DATASET 3 : Vehicle**

# %%
vehicle = pd.read_json("vehicle.json")
vehicle
# Out:
# C:\Users\basil\AppData\Local\Temp\ipykernel_10480\2558437397.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   vehicle = pd.read_json("vehicle.json")
# C:\Users\basil\AppData\Local\Temp\ipykernel_10480\2558437397.py:1: FutureWarning: The behavior of 'to_datetime' with 'unit' when parsing strings is deprecated. In a future version, strings will be parsed as datetime strings, matching the behavior without a 'unit'. To retain the old behavior, explicitly cast ints or floats to numeric type before calling to_datetime.
#   vehicle = pd.read_json("vehicle.json")
# ...

# %%
vehicle.set_index('Nation', inplace=True)

# Plotting the data for all countries
vehicle.T.plot(kind='line', figsize=(10, 6)) # Each row in the transposed DataFrame represents a year

# Adding labels and title for clarity
plt.xlabel('Year', fontsize=12)
plt.ylabel('Vehicles (millions)', fontsize=12)
plt.title('Number of vehicles sold each year', fontsize=16)

# Show the legend
plt.legend(title="Country", bbox_to_anchor=(1.05, 1), loc='upper left')

# %% [markdown]
# *For some reason, UAE had 0 cars sold, in 2017 and 2018*

# %%
vehicle_filtered = vehicle[['2022']]
vehicle_filtered # Filtering for the most recent year
# Out:
#              2022
# Nation
# UK        1614063
# UAE        171414
# Malaysia   544838

# %%
vehicle.plot.pie(y='2022', autopct='%1.1f%%', 
    colors=["red","green","blue"], # Classic RGB
    figsize=(6, 6), 
    legend=False, # No legend as labels are already there
    wedgeprops={'edgecolor': 'black', 'linewidth': 1},  # Add black edge to the slices (makes it look cleaner)
)
# Out:
# <Axes: ylabel='2022'>

# %% [markdown]
# *The pie chart shows that the UK dominates GDP (69.3%), followed by Malaysia (23.4%), while UAE has the smallest share (7.4%) in 2023.*

# %% [markdown]
# ***Now that we have individual insights from the 3 datasets, lets try to connect them and find out more.***

# %% [markdown]
# **GDP x Population**

# %%
GDP2023_duplicate = GDP2023 # Checking the dataset and just duplicating it.
GDP2023_duplicate = GDP2023_duplicate.reset_index() # Resetting index
GDP2023_duplicate
# Out:
#            Country Name             2023
# 0  United Arab Emirates  514130432653.08
# 1        United Kingdom 3380854520809.54
# 2              Malaysia  399705169318.48

# %%
WPP_population_by_country
# Out:
#                Location   PopTotal
# 2        United Kingdom 4279340.23
# 0              Malaysia 1312630.44
# 1  United Arab Emirates  212847.99

# %%
WPP_population_by_country = WPP_population_by_country.rename(columns={'Location': 'Country Name'})
WPP_population_by_country
# Out:
#            Country Name   PopTotal
# 2        United Kingdom 4279340.23
# 0              Malaysia 1312630.44
# 1  United Arab Emirates  212847.99

# %%
GDP_population_merged = GDP2023.merge(WPP_population_by_country, on="Country Name") #Merging the 2 tables
GDP_population_merged
# Out:
#            Country Name             2023   PopTotal
# 0  United Arab Emirates  514130432653.08  212847.99
# 1        United Kingdom 3380854520809.54 4279340.23
# 2              Malaysia  399705169318.48 1312630.44

# %%
GDP_population_merged["GDP per Capita"] = GDP_population_merged["2023"] / GDP_population_merged["PopTotal"]
GDP_population_merged # Finding GDP per Capita for average analysis.
# Out:
#            Country Name             2023   PopTotal  GDP per Capita
# 0  United Arab Emirates  514130432653.08  212847.99      2415481.78
# 1        United Kingdom 3380854520809.54 4279340.23       790041.07
# 2              Malaysia  399705169318.48 1312630.44       304507.01

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for GDP
ax1.bar(GDP_population_merged["Country Name"], 
        GDP_population_merged["2023"], 
        color='skyblue', 
        label="GDP (trillion USD)")

ax1.set_xlabel("Country")
ax1.set_ylabel("GDP (trillion USD)", color="blue")
ax1.tick_params(axis='y', labelcolor="blue")
ax1.set_xticklabels(GDP_population_merged["Country Name"], rotation=45)

# Secondary y-axis for population
ax2 = ax1.twinx()
ax2.plot(GDP_population_merged["Country Name"], 
         GDP_population_merged["PopTotal"], 
         color='red', 
         marker="o", 
         linewidth=2, 
         label="Population (millions)")

ax2.set_ylabel("Population (millions)", color="red")
ax2.tick_params(axis='y', labelcolor="red")

# Titles and grid
plt.title("GDP and Population Comparison (2023)")
fig.tight_layout()
plt.grid(axis='y', linestyle="--", alpha=0.5)

plt.show()
# Out:
# C:\Users\basil\AppData\Local\Temp\ipykernel_10480\3892482839.py:12: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax1.set_xticklabels(GDP_population_merged["Country Name"], rotation=45)

# %% [markdown]
# *Even though the axis are not matched, we can get an idea of how different each country's GDP is in relation to their population.*

# %%
# Ensure 'Country Name' is the index
GDP_population_merged.set_index('Country Name', inplace=True)

# Plot horizontal bar chart
GDP_population_merged['GDP per Capita'].plot.barh(
    figsize=(8, 6),
    color='skyblue',
    edgecolor='black'
)

# Add labels and title
plt.xlabel("GDP per Capita (million USD)", fontsize=12)
plt.ylabel("Country", fontsize=12)
plt.title("GDP per Capita by Country (2023)", fontsize=14)

plt.show()

# %% [markdown]
# *UAE's GDP per Capita is the highest being almost 2.5 million, the UK is just below 1 and Malaysia being less than half of the UK.*

# %% [markdown]
# **Now that we have GDP per capita, lets take it a step further and get GDP per worker**

# %%
WPP_grouped2 = WPP_grouped[WPP_grouped['Time'] == 2023]

# %%
WPP_grouped2 = WPP_grouped2.rename(columns={'PopTotal': 'WorkingPop'})

# %%
WPP_grouped2 = WPP_grouped2.rename(columns={'Location': 'Country Name'})
WPP_grouped2
# Out:
#              Country Name  Time   index  AgeGrpStart  WorkingPop
# 73               Malaysia  2023  168935         1725    23456.68
# 147  United Arab Emirates  2023  505931         1725     8426.85
# 221        United Kingdom  2023  328455         1710    39358.66

# %%
GDP2023_duplicate
# Out:
#            Country Name             2023
# 0  United Arab Emirates  514130432653.08
# 1        United Kingdom 3380854520809.54
# 2              Malaysia  399705169318.48

# %%
GDP_working_population_merged = WPP_grouped2.merge(GDP2023_duplicate, on="Country Name") #Merging the 2 tables
GDP_working_population_merged
# Out:
#            Country Name  Time   index  AgeGrpStart  WorkingPop  \
# 0              Malaysia  2023  168935         1725    23456.68
# 1  United Arab Emirates  2023  505931         1725     8426.85
# 2        United Kingdom  2023  328455         1710    39358.66
#
#               2023
# 0  399705169318.48
# 1  514130432653.08
# 2 3380854520809.54

# %%
GDP_working_population_merged["GDP per working population"] = GDP_working_population_merged["2023"] / GDP_working_population_merged["WorkingPop"]
GDP_working_population_merged # Finding GDP per worker for average analysis.
# Out:
#            Country Name  Time   index  AgeGrpStart  WorkingPop  \
# 0              Malaysia  2023  168935         1725    23456.68
# 1  United Arab Emirates  2023  505931         1725     8426.85
# 2        United Kingdom  2023  328455         1710    39358.66
#
#               2023  GDP per working population
# 0  399705169318.48                 17040141.03
# 1  514130432653.08                 61011015.59
# 2 3380854520809.54                 85898627.25

# %%
ax = GDP_working_population_merged.plot.bar(
    x='Country Name', 
    y='GDP per working population', 
    legend=False, 
    color=['blue', 'green', 'red']
)

# Add labels and title
plt.title('GDP per Working Population (2023)', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=12)
plt.ylabel('GDP per Working Population (10 millions)', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# *The UK has the highest GDP per worker and the UAE is not too far behind, Malaysia being the loswest in 2023.*

# %% [markdown]
# **Now lets see how many vehicles there are with regards to the population.**

# %%
vehicle_filtered2 = vehicle_filtered.reset_index(level=0) # Wasn't resetting for some reason
vehicle_filtered2
# Out:
#      Nation     2022
# 0        UK  1614063
# 1       UAE   171414
# 2  Malaysia   544838

# %%
WPP_population_by_country
# Out:
#            Country Name   PopTotal
# 2        United Kingdom 4279340.23
# 0              Malaysia 1312630.44
# 1  United Arab Emirates  212847.99

# %%
vehicle_filtered2.rename(columns={'Nation': 'Country Name'}, inplace=True)
vehicle_filtered2 = vehicle_filtered2.replace({
    'UK': 'United Kingdom',
    'UAE': 'United Arab Emirates'
})
vehicle_filtered2
# Out:
#            Country Name     2022
# 0        United Kingdom  1614063
# 1  United Arab Emirates   171414
# 2              Malaysia   544838

# %%
vehicle_population = WPP_population_by_country.merge(vehicle_filtered2, on="Country Name") #Merging the 2 tables
vehicle_population
# Out:
#            Country Name   PopTotal     2022
# 0        United Kingdom 4279340.23  1614063
# 1              Malaysia 1312630.44   544838
# 2  United Arab Emirates  212847.99   171414

# %%
vehicle_population["Vehicle per person"] = vehicle_population["PopTotal"] / vehicle_population["2022"]
vehicle_population # Finding Vehicles ratio with people
# Out:
#            Country Name   PopTotal     2022  Vehicle per person
# 0        United Kingdom 4279340.23  1614063                2.65
# 1              Malaysia 1312630.44   544838                2.41
# 2  United Arab Emirates  212847.99   171414                1.24

# %%
ax = vehicle_population.plot.bar(
    x='Country Name', 
    y='Vehicle per person', 
    legend=False, 
    color=['blue', 'green', 'red']
)

# Add labels and title
plt.title('People per vehicle (2022)', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=12)
plt.ylabel('People per vehicle', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# *The smaller bars mean that there are more vehicles, for every 2.65 people in the UK, there is 1 vehicle. The UAE has the least people per vehicle (1.24). The reason could be that the UK has an excellent public transport system, meaning less people opt for cars.*

# %% [markdown]
# **Now lets find the working population and vehicles insight.**

# %%
vehicle_filtered2
# Out:
#            Country Name     2022
# 0        United Kingdom  1614063
# 1  United Arab Emirates   171414
# 2              Malaysia   544838

# %%
WPP_grouped2
# Out:
#              Country Name  Time   index  AgeGrpStart  WorkingPop
# 73               Malaysia  2023  168935         1725    23456.68
# 147  United Arab Emirates  2023  505931         1725     8426.85
# 221        United Kingdom  2023  328455         1710    39358.66

# %%
vehicle_working_population = WPP_grouped2.merge(vehicle_filtered2, on="Country Name") #Merging the 2 tables
vehicle_working_population
# Out:
#            Country Name  Time   index  AgeGrpStart  WorkingPop     2022
# 0              Malaysia  2023  168935         1725    23456.68   544838
# 1  United Arab Emirates  2023  505931         1725     8426.85   171414
# 2        United Kingdom  2023  328455         1710    39358.66  1614063

# %%
vehicle_working_population["Vehicle per working person"] = vehicle_working_population["2022"] / vehicle_working_population["WorkingPop"]
vehicle_working_population # Finding Vehicles ratio with people
# Out:
#            Country Name  Time   index  AgeGrpStart  WorkingPop     2022  \
# 0              Malaysia  2023  168935         1725    23456.68   544838
# 1  United Arab Emirates  2023  505931         1725     8426.85   171414
# 2        United Kingdom  2023  328455         1710    39358.66  1614063
#
#    Vehicle per working person
# 0                       23.23
# 1                       20.34
# 2                       41.01

# %%
ax = vehicle_working_population.plot.bar(
    x='Country Name', 
    y='Vehicle per working person', 
    legend=False, 
    color=['blue', 'green', 'red']
)

# Add labels and title
plt.title('Working people per vehicle (2022)', fontsize=14, fontweight='bold')
plt.xlabel('Country', fontsize=12)
plt.ylabel('Working people per vehicle', fontsize=12)

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Show gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %% [markdown]
# *When we filter for working population only, we can see that there are a lot more workers than cars. It could be due to people opting for public transport.*
